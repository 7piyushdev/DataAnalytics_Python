# %% [markdown]
# Q1: What is the difference between a function and a method in Python?
#
#   -> A function is a block of reusable code that is defined independently and can be called directly using its name.
#   whereas
#   A method is a function that is associated with an object or a class and is called using that object or class.

# %% [markdown]
# Function example

# %%
def add(a, b):
    return a + b

print(add(3, 5))

# %% [markdown]
# Method Example

# %%
text = "python"
print(text.upper())

# %% [markdown]
# Q2: . Explain the concept of function arguments and parameters in Python.
#
# Parameters
#
# Parameters are variables listed in the function definition.
# They act as placeholders to receive values.
#
# Arguments
#
# Arguments are the actual values passed to the function when it is called.

# %%
def multiply(x, y):   # x and y are parameters
    return x * y

result = multiply(4, 5)   # 4 and 5 are arguments
print(result)

# %% [markdown]
# Q3: What are the different ways to define and call a function in Python?
#
#   -> Simple function call

# %%
def say_hello():
    print("Hello World")

say_hello()
# Out:
# Hello World

# %% [markdown]
# b) Function with parameters

# %%
def square(num):
    return num * num

print(square(6))
# Out:
# 36

# %% [markdown]
# c) Function with return value

# %%
def add(a, b):
    return a + b

result = add(10, 20)
print(result)
# Out:
# 30

# %% [markdown]
# d) Lambda/Anonymous functions

# %%
square = lambda x: x * x
print(square(5))

# %% [markdown]
# e) Functions with variable arguments

# %%
def average(*args):
    return sum(args) / len(args)

print(average(10, 20, 30))
# Out:
# 20.0

# %% [markdown]
# Q4: What is the purpose of the `return` statement in a Python function?
#
#   -> The purpose of `return` statement is to send back the value to the caller, end the execution of the function and allow returned value to be stored

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print(result)

# %% [markdown]
# Q5: What are iterators in Python and how do they differ from iterables?
#
#   -> Iterable
#
# An iterable is an object that can be looped over using a for loop.
# It has the __iter__() method.
#
# Examples: list, tuple, string, set, dictionary
#
#   b) Iterator
#
# An iterator is an object that:
#
# Produces values one at a time
#
# Keeps track of the current state
#
# Has both __iter__() and __next__() methods

# %%
nums = [1, 2, 3]       # Iterable
it = iter(nums)       # Iterator

print(next(it))
print(next(it))

# %% [markdown]
#   Q6: Explain the concept of generators in Python and how they are defined.
#
#   -> A generator function is a special type of function that returns an iterator object. Instead of using return to send back a single value, generator functions use yield to produce a series of results over time. The function pauses its execution after yield, maintaining its state between iterations.

# %%
def even_generator(limit):
    for i in range(2, limit+1, 2):
        # Yield also retuns the item but it keeps the function and the state in the memory
        yield i

# <generator object even_generator at 0x00000240A3CA02E0>
print(even_generator(10))

for num in even_generator(10):
    print(num)

# %% [markdown]
# Q7: What are the advantages of using generators over regular functions?
#
#   -> Memory Efficiency
#
# Generators do not store all values in memory at once
#
# Values are generated on demand using yield
#
#   b) Lazy Evaluation
#
# Values are produced only when needed
#
# Improves performance when not all values are required
#
#   c) 4. Maintains State Automatically
#
# Execution resumes from the last yield
#
# No need to manually track iteration state

# %% [markdown]
# Q8: What is a lambda function in Python and when is it typically used?
#
#   -> A lambda function is a small, anonymous function defined using the lambda keyword. used for short operations when the functions are needed temporarily

# %%
area = lambda x, y: x * y

print(area(2,3))

# %% [markdown]
# Q9: Explain the purpose and usage of the `map()` function in Python
#
#   -> map() applies a given function to each item of an iterable and returns a map object (iterator).
#
#   map(function, iterable)

# %%
numbers = [1, 2, 3, 4]

def square(x):
    return x * x

result = map(square, numbers)
print(list(result))

# %% [markdown]
# Q 10:  What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
#   -> map(), filter(), and reduce() are higher-order functions used for processing iterables in a functional programming style. Each serves a different purpose.
#
#   filter function -> Filters elements from an iterable based on a condition (returns only elements that evaluate to True).
#
#   reduce function -> Reduces an iterable to a single value by applying a function cumulatively.
#       from functools import reduce
#       reduce(function, iterable)

# %% [markdown]
# Q 11:  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13]
#
#   ->   ![Answer 11.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# **Practical Questions**
#
# Q1: Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
nums = [1,2,4,6,7,9,11,14]
def even_sum(nums):
    sum = 0
    for num in nums:
        if num % 2 == 0:
            sum += num
    return sum

print(even_sum(nums))

# %% [markdown]
# Q2: Create a Python function that accepts a string and returns the reverse of that string.

# %%
str = "john cena"
def reverse(str):
    return str[::-1]

print(reverse(str))

# %% [markdown]
# Q3: Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
intg = [1,2,3,5,7]
def square(intg):
    return [i**2 for i in intg]

print(square(intg))

# %% [markdown]
# Q4: Write a Python function that checks if a given number is prime or not from 1 to 200

# %%
def is_prime(n):
    if n <= 1:
        return False

    for i in range(2, n):
        if n % i == 0:
            return False

    return True
print(is_prime(21))

# %% [markdown]
# Q5: Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.count = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration

        value = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return value

fib = Fibonacci(6)

for i in fib:
    print(i)

# %% [markdown]
# Q 6:  Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(limit):

    for i in range(limit + 1):
        yield 2 ** i

powers_gen = powers_of_two(5)

for power in powers_gen:
    print(power)

# %% [markdown]
# Q7: Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_lines(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line

for line in read_file_lines("sample.txt"):
    print(line)

# %% [markdown]
# Q8: se a lambda function in Python to sort a list of tuples based on the second element of each tuple

# %%
data = [(1, 3), (4, 1), (2, 2)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
# Out:
# [(4, 1), (2, 2), (1, 3)]

# %% [markdown]
# Q9: Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius = [0, 10, 20, 30, 40]

fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

print(fahrenheit)

# %% [markdown]
# Q10: Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
text = "Hello World"

vowels = "aeiouAEIOU"

result = "".join(filter(lambda ch: ch not in vowels, text))

print(result)

# %% [markdown]
# Q 11: Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %%
result = list(
    map(
        lambda order: (
            order[0],
            order[2] * order[3] + 10 if order[2] * order[3] < 100 else order[2] * order[3]
        ),
        orders
    )
)

print(result)
