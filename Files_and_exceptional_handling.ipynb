# %% [markdown]
# .............   Files, exceptional handling, logging and
# memory management Questions .................
#
#
# Q1: What is the difference between interpreted and compiled languages
#
# Ans: Compiled languages convert the entire source code into machine code before execution, making them faster at runtime.
# Interpreted languages execute code line-by-line at runtime, which makes them more flexible but slower.
#
#  Example:
# C/C++ → Compiled | Python/JavaScript → Interpreted
# Note: Python is first compiled to bytecode, then interpreted by the Python Virtual Machine.
#
# Q2: What is exception handling in Python
#
# Ans: Exception handling is a mechanism to catch and handle runtime errors so the program does not crash and can continue running safely.
#
# Python uses:
#
# try
# except
# else
# finally
#
# Q3: What is the purpose of the finally block in exception handling
#
# Ans: The purpose of finally block is it always executes, whether an exception occurs or not. Ex -> used during the DB connection, close file handling, network socketing.
#
# Q4: What is logging in Python
#
# Ans: Logging is used to record messages about program execution, errors, and system behavior instead of using print().
#
# It helps in:
# Debugging
# Monitoring production systems
# Tracking issues
#
# Log levels: DEBUG, INFO, WARNING, ERROR, CRITICAL
#
# Q5: What is the significance of the __del__ method in Python
#
# Ans: __del__ is a destructor method that is called when an object is about to be destroyed by the garbage collector.
#
# It is used for cleanup tasks, but:
# Not reliable for critical resource handling because garbage collection timing is unpredictable.
#
# Q6: What is the difference between import and from ... import in Python
#
# Ans: import module → Imports the whole module and keeps the namespace.
#
# from module import item → Imports only specific items directly.
#
# >> Best practice is to use import module in large projects to avoid name conflicts.
#
# Q7: How can you handle multiple exceptions in Python
#
# Ans: you cando it with multiple except block or single block as well
#
# try:
#     print(10 / 0)
# except (ValueError, ZeroDivisionError):
#     print("Invalid input or division by zero")
#
# Q8: What is the purpose of the with statement when handling files in Python
#
# Ans: With statement ensures that the file is properly closed after its block finishes — even if an error occurs.
#
# use case: Safely opening and closing files without manually calling close().
#
# Q9: What is the difference between multithreading and multiprocessing
#
# Ans: Multithreading
#
# Runs multiple threads in the same process.
# Shares memory space.
# Faster context switching.
# Limited by Python’s GIL for CPU-bound tasks.
#
# Multiprocessing
#
# Runs multiple processes.
# Each has its own memory space.
# True parallelism for CPU-bound tasks.
# More memory usage.
#
#  Use threads for I/O-bound, processes for CPU-bound.
#
# Q10: What are the advantages of using logging in a program
#
# Ans:Looging Helps in debugging
# Tracks program execution
# Records errors and warnings
# Can store logs in files
# Supports severity levels
#
# Better than print() for real world applications.
#
# Q11: What is memory management in Python
#
# Ans: Memory management is how Python allocates, uses, and frees the memory space for the objects during the program execution.
#
# Python uses:
#
# Private heap
# Reference counting
# Garbage collection
#
# Q12: What are the basic steps involved in exception handling in Python
#
# Ans:
# Put risky code inside try
# Handle errors in except
# Run code when no exception in else
# Cleanup code in finally
#
# Q13: Why is memory management important in Python
#
# Ans: Prevents memory leaks
# Improves performance
# Frees unused memory
# Ensures program stability
#
# Q14: What is the role of try and except in exception handling
#
# Ans: try used to wrap the program which we want to execute which may cause error and except handles and catches the possible errors that program could give.
#
# Q15 How does Python's garbage collection system work
#
# when some variable or object is deleted from the program and doesn't have or need any reference in the memory garbage collector will se that this particular program doesn't have any reference in the memory so that varibale/object will be garbage colleted  by the python internally and the values will be cleaned. Note: it make take some time internally.
#
# Q16 What is the purpose of the else block in exception handling
#
# Ans: The else block runs only if no exception occurs in the try block.
#
# Used for code that should execute when everything goes fine.
#
# Q17 What are the common logging levels in Python
#
# Ans: the common logging levels in Python are:
# DEBUG
# INFO
# WARNING
# ERROR
# CRITICAL
#
# Q18: What is the difference between os.fork() and multiprocessing in Python
#
# Ans: os.fork() = Make a copy of the current program exactly as it is
# Imagine you are working alone in a factory.
# You press a button and suddenly… a copy of you appears 😄
#
# That copy:
# Has the same tools and memory as you
# Starts working from the same point
# Only works on Linux/Mac
#
# multiprocessing = Start new programs (workers) cleanly and safely
#
# Instead of copying yourself, you hire new workers.
#
# Each worker:
#
# Has their own workspace
# Gets only the tools you give them
# Works independently
# Works on all operating systems (Windows, Linux, Mac)
#
# Q19: What is the importance of closing a file in Python
#
# Ans: Closing a file releases system resources and ensures that all data is properly written (flushed) to the file.
# If a file is not closed, it may cause memory leaks or data corruption.
#
# Best practice is to Use the with statement to auto-close files.
#
# Q20: What is the difference between file.read() and file.readline() in Python
#
# Ans: file.read() reads the entire file at once.
# file.readline() reads one line at a time.
#
# Q21: What is the logging module in Python used for
#
# Ans: The logging module is used to record program messages such as errors, warnings, and execution flow for debugging and monitoring.
#
# Q22 What is the os module in Python used for in file handling
#
# Ans: The os module is used to interact with the operating system, such as:
#
# Creating/deleting files and folders
# Navigating directories
# Getting file paths and environment info
#
#  Example: os.mkdir(), os.remove(), os.getcwd()
#
# Q23 What are the challenges associated with memory management in Python
#
# Ans: Memory leaks from unused objects
# Handling circular references
# High memory usage in large programs
# Unpredictable garbage collection timing
#
# Q24  How do you raise an exception manually in Python
#
# Ans: using the "raise" keyword you can raise an exception manually in Python
# raise ValueError("Invalid input provided")
#
# Q25 Why is it important to use multithreading in certain applications ?
#
# Ans: Multithreading improves performance by running multiple tasks at the same time, especially for I/O-bound tasks like file downloads, API calls, or user interactions.
#
# It helps keep applications responsive and faster.

# %% [markdown]
# ------ PRACTICAL QUESTIONS ---------

# %% [markdown]
# Q1: How can you open a file for writing in Python and write a string to it ?

# %%
with open("example.txt", "w") as file:
    file.write("Hello, this is a sample string written to the file.")

# %% [markdown]
# Q2: Write a Python program to read the contents of a file and print each line

# %%
with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())

# %% [markdown]
# Q3: How would you handle a case where the file doesn't exist while trying to open it for reading

# %%
try:
    with open("missing_file.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("Error: File does not exist.")

# %% [markdown]
# Q4: Write a Python script that reads from one file and writes its content to another file

# %%
with open("source.txt", "r") as src:
    with open("destination.txt", "w") as dest:
        for line in src:
            dest.write(line)

# %% [markdown]
# Q5: How would you catch and handle division by zero error in Python

# %%
try:
    result = 10 / 0
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

# %% [markdown]
# Q6: Write a Python program that logs an error message to a log file when a division by zero exception occurs

# %%
import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    x = int(input("Enter a number: "))
    result = 10 / x
    print("Result:", result)
except ZeroDivisionError:
    logging.error("Division by zero occurred")
    print("Error: Cannot divide by zero")

# %% [markdown]
# Q7: How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")

# %% [markdown]
# Q8: Write a program to handle a file opening error using exception handling

# %%
try:
    with open("data.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("Error: File not found")
# Out:
# Error: File not found

# %% [markdown]
# Q9: How can you read a file line by line and store its content in a list in Python

# %%
lines_list = []

with open("data.txt", "r") as file:
    for line in file:
        lines_list.append(line.strip())

print(lines_list)

# %% [markdown]
# Q10: How can you append data to an existing file in Python

# %%
with open("data.txt", "a") as file:
    file.write("\nThis is new appended text.")

# %% [markdown]
# Q11: Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist

# %%
data = {"name": "John", "age": 25}

try:
    print(data["salary"])
except KeyError:
    print("Error: Key does not exist in dictionary")

# %% [markdown]
# Q12: Write a program that demonstrates using multiple except blocks to handle different types of exceptions

# %%
try:
    x = int(input("Enter a number: "))
    y = 10 / x
    print(y)
except ValueError:
    print("Error: Invalid input")
except ZeroDivisionError:
    print("Error: Cannot divide by zero")

# %% [markdown]
# Q13: How would you check if a file exists before attempting to read it in Python

# %%
import os

if os.path.exists("data.txt"):
    with open("data.txt", "r") as file:
        print(file.read())
else:
    print("File does not exist")
# Out:
# File does not exist

# %% [markdown]
# Q14: Write a program that uses the logging module to log both informational and error messages

# %%
import logging

logging.basicConfig(filename="app.log", level=logging.INFO)

logging.info("Program started")

try:
    x = int(input("Enter a number: "))
    result = 10 / x
    logging.info(f"Result is {result}")
except Exception as e:
    logging.error(f"An error occurred: {e}")

# %% [markdown]
# Q15: Write a Python program that prints the content of a file and handles the case when the file is empty

# %%
try:
    with open("data.txt", "r") as file:
        content = file.read()
        if content:
            print(content)
        else:
            print("The file is empty")
except FileNotFoundError:
    print("File not found")

# %% [markdown]
# Q16: Demonstrate how to use memory profiling to check the memory usage of a small program

# %%
from memory_profiler import profile

@profile
def demo():
    a = [i for i in range(100000)]
    return a

demo()

# first install the memory_profiler and then run the command python -m memory_profiler demo.py

# %% [markdown]
# Q17: Write a Python program to create and write a list of numbers to a file, one number per line

# %%
numbers = [1, 2, 3, 4, 5, 10, 20]

with open("numbers.txt", "w") as file:
    for num in numbers:
        file.write(f"{num}\n")

# %% [markdown]
# Q18: How would you implement a basic logging setup that logs to a file with rotation after 1MB

# %%
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler("app.log", maxBytes=1_000_000, backupCount=3)
logging.basicConfig(level=logging.INFO, handlers=[handler])

logging.info("This is an info message")
logging.error("This is an error message")

# %% [markdown]
# Q19: Write a program that handles both IndexError and KeyError using a try-except block

# %%
data_list = [10, 20, 30]
data_dict = {"a": 1, "b": 2}

try:
    print(data_list[5])
    print(data_dict["c"])
except IndexError:
    print("Error: List index out of range")
except KeyError:
    print("Error: Key not found in dictionary")
# Out:
# Error: List index out of range

# %% [markdown]
# Q20: How would you open a file and read its contents using a context manager in Python

# %%
with open("data.txt", "r") as file:
    content = file.read()
    print(content)

# %% [markdown]
# Q21: Write a Python program that reads a file and prints the number of occurrences of a specific word

# %%
word = "python"
count = 0

with open("data.txt", "r") as file:
    for line in file:
        count += line.lower().split().count(word.lower())

print(f"'{word}' appears {count} times.")

# %% [markdown]
# Q22: How can you check if a file is empty before attempting to read its contents

# %%
import os

if os.path.exists("data.txt") and os.path.getsize("data.txt") > 0:
    with open("data.txt", "r") as file:
        print(file.read())
else:
    print("File is empty or does not exist")

# %% [markdown]
# Q23: Write a Python program that writes to a log file when an error occurs during file handling

# %%
import logging

logging.basicConfig(filename="file_errors.log", level=logging.ERROR)

try:
    with open("missing.txt", "r") as file:
        print(file.read())
except Exception as e:
    logging.error(f"File handling error: {e}")
    print("An error occurred. Check the log file.")
